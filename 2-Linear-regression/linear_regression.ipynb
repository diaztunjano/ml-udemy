# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### 1. Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### 2. Importing the dataset and creating the matrix of features and the dependent variable vector
#
# - Features = Independent variables = Matrix of features = X
# - Target = Dependent variable = Vector of target values = y

# %%
clean_data = pd.read_csv('./data/cost_revenue_clean.csv')
clean_data.describe()

X = pd.DataFrame(clean_data, columns=['production_budget_usd'])
y = pd.DataFrame(clean_data, columns=['worldwide_gross_usd'])

# %% [markdown]
# ### 3. Plotting the dataset

# %%
plt.scatter(X, y, alpha=0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# ### 4. Creating Linear Regression model and fitting it to the dataset

# %%
regression = LinearRegression()
regression.fit(X, y)
regression.coef_ #theta_1 - slope
regression.intercept_ #theta_0 - intercept
# Out:
# array([-7236192.72913988])

# %% [markdown]
# ### 5. Plot with the regression line

# %%
y_prediction = regression.predict(X)

plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, y_prediction, color='red', linewidth=3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# ### 6. Evaluating the model

# %%
# R-squared
r_2 = regression.score(X, y)
print(r_2)
# Out:
# 0.5496485356985729
